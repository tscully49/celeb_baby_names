# %%
import pandas as pd
import csv

frame = pd.DataFrame()
list_ = []

df = pd.read_csv("stateNames1.csv",index_col=None, header=0)
df2 = pd.read_csv("stateNames2.csv",index_col=None, header=0)
    
list_.append(df)
list_.append(df2)
frame = pd.concat(list_)
frame['total_count'] = 0
frame['percent_change'] = 0

# %%
years = list(range(1910,1954))
framesByYear = {}

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

for year in years:
    for state in states:
        framesByYear[state + "-" + str(year)] = frame[(frame['State'] == state) & (frame['Year'] == year)]
        print(state + "-" + str(year))
# Out:
# AL-1910
# AK-1910
# AZ-1910
# AR-1910
# CA-1910
# CO-1910
# CT-1910
# DC-1910
# DE-1910
# FL-1910
# GA-1910
# HI-1910
# ID-1910
# IL-1910
# IN-1910
# IA-1910
# KS-1910
# KY-1910
# LA-1910
# ME-1910
# MD-1910
# MA-1910
# MI-1910
# MN-1910
# MS-1910
# MO-1910
# MT-1910
# NE-1910
# NV-1910
# NH-1910
# NJ-1910
# NM-1910
# NY-1910
# NC-1910
# ND-1910
# OH-1910
# OK-1910
# OR-1910
# PA-1910
# RI-1910
# SC-1910
# SD-1910
# TN-1910
# TX-1910
# UT-1910
# VT-1910
# VA-1910
# WA-1910
# WV-1910
# WI-1910
# WY-1910
# AL-1911
# AK-1911
# AZ-1911
# AR-1911
# CA-1911
# CO-1911
# CT-1911
# DC-1911
# DE-1911
# FL-1911
# GA-1911
# HI-1911
# ID-1911
# IL-1911
# IN-1911
# IA-1911
# KS-1911
# KY-1911
# LA-1911
# ME-1911
# MD-1911
# MA-1911
# MI-1911
# MN-1911
# MS-1911
# MO-1911
# MT-1911
# NE-1911
# NV-1911
# NH-1911
# NJ-1911
# NM-1911
# NY-1911
# NC-1911
# ND-1911
# OH-1911
# OK-1911
# OR-1911
# PA-1911
# RI-1911
# SC-1911
# SD-1911
# TN-1911
# TX-1911
# UT-1911
# VT-1911
# VA-1911
# WA-1911
# WV-1911
# ...

# %%
'''if (year == 1910):
            frame['total_count'] = frame['Count']
        else:
            tempInt = 0
            tempYear = year
            while year >= 1910:
                tempInt = tempInt + frame[(frame['State'] == state) & (frame['Year'] == tempYear) & (frame['Name']) == name]
                tempYear = tempYear + 1
            frame[]'''
            
        
        
#print(framesByYear[MO-1910])
